# %%
# Multiply

a=int(input("Enter the 1st no.: "))
b=int(input("Enter the 2nd no.: "))
print("The multiplication result is : ",a*b)
# Out:
# Enter the 1st no.: 3
# Enter the 2nd no.: 10
# The multiplication result is :  30

# %%
# Greater & smaller

a,b=map(int,input("Enter 2 no. separated by space: ").split())
if a<b:
 print(f"{b} is greater than {a}")
elif a>b:
 print(f"{a} is greater than {b}")
else :
 print("Both are equal")
# Out:
# Enter 2 no. separated by space: 2 4
# 4 is greater than 2

# %%
# Multiplication table

a=int(input("Enter a no.: "))
for i in range (1,11):
 print(f"{a}*{i}={a*i}")
# Out:
# Enter a no.: 2
# 2*1=2
# 2*2=4
# 2*3=6
# 2*4=8
# 2*5=10
# 2*6=12
# 2*7=14
# 2*8=16
# 2*9=18
# 2*10=20

# %%
# List Operation

x=[]
n=int(input("Enter the no. of elements: "))
for i in range(n):
  num=int(input(f"Enter the {i+1} element: "))
  x.append(num)
print(x)
print(max(x))
print(min(x))
print(len(x))
print(x[0])
print(x[-1])
print(sum(x))
# Out:
# Enter the no. of elements: 2
# Enter the 1 element: 5
# Enter the 2 element: 500
# [5, 500]
# 500
# 5
# 2
# 5
# 500
# 505

# %%
# Dictionary

car={"Brand":"Toyota",
   "Model":"Corola",
   "Year":2020}
print(car["Brand"])
car["Year"]=2022
print(car["Year"])
print(car)
# Out:
# Toyota
# 2022
# {'Brand': 'Toyota', 'Model': 'Corola', 'Year': 2022}

# %%
# User Dictionary

dict={}
n=int(input("Enter no. of elements: "))
for i in range(n):
 key=input(f"Enter {i+1} key: ")
 val=input(f"Enter '{key}' value/name: ")
 dict[key]=val
print("\nYour Dictionary")
print(dict)
# Out:
# Enter no. of elements: 2
# Enter 1 key: Car
# Enter 'Car' value/name: F1
# Enter 2 key: Year
# Enter 'Year' value/name: 2026
#
# Your Dictionary
# {'Car': 'F1', 'Year': '2026'}

# %%
# Find the unique item

arr = list(map(int, input("Enter your elements: ").split()))

# Step 1: Build frequency dictionary
counts = {}

for num in arr:
    if num in counts:
        counts[num] += 1   # Increment count if we've seen it before
    else:
        counts[num] = 1    # Set initial count to 1 for new numbers

# Step 2: Collect keys that appeared exactly once
result = []

for num in counts:
    if counts[num] == 1:
        result.append(num)

print(f"The unique numbers are: {result}")
# Out:
# Enter your elements: 1 2 3 4 5 3 2 1
# The unique numbers are: [4, 5]

# %%
# Function

def add_numbers(a, b):
    result = a + b  #local variable
    return result  # Sends the calculated value back

# Store the returned value in a variable  # Global variable (keyword to force local variable in function to be global is 'global')
x,y=map(int,input("Enter 2 no. separated by space: ").split())
total = add_numbers(x,y)

print(f"The total is: {total}") # Output: The total is: 30
# Out:
# Enter 2 no. separated by space: 20 40
# The total is: 60

# %%
# Function

def check_even_odd(a):
 if a%2==0:
  return 'even'
 else:
  return 'odd'


x=int(input("Enter a no.: "))
main=check_even_odd(x)
print(f"The no. is {main}")
# Out:
# Enter a no.: 2
# The no. is even

# %%
# Set

# 1. Initialize an empty set
user_set = set()

# 2. Ask how many elements
n = int(input("How many items do you want to add? "))

# 3. Add items using a loop
for i in range(n):
    val = int(input(f"Enter item {i + 1}: "))
    user_set.add(val)
# Uses .add() for sets!

print("\nFinal Unique Set:", user_set)
# Out:
# How many items do you want to add? 2
# Enter item 1: 500
# Enter item 2: 1000
#
# Final Unique Set: {1000, 500}

# %%
# List to set

x=[]
n=int(input("Enter the no of elements: "))
for i in range (n):
 num=int(input(f"Enter the {i+1} element: "))
 x.append(num)
y=list(set(x))
print(y)
print("Greatest no.: ",max(y))
print("Smallest no.: ",min(y))
# Out:
# Enter the no of elements: 2
# Enter the 1 element: 3
# Enter the 2 element: 4
# [3, 4]
# Greatest no.:  4
# Smallest no.:  3

# %%
# Tuple

x=tuple(input("Enter the colors: ").split())

print(x)
print(type(x))
# Out:
# Enter the colors: Red green blue
# ('Red', 'green', 'blue')
# <class 'tuple'>

# %%
# List to tuple

x=[]
n=int(input("Enter the no of elements: "))
for i in range (n):
 z=(input(f"Enter the {i+1} element: "))
 if z.isdigit(): # Checks if int or alpha
  val=int(z)
  x.append(val)
 else:
  x.append(z)
y=tuple(set(x))
print(y)
print(type(y))
print(type(x[0]))
# Out:
# Enter the no of elements: 2
# Enter the 1 element: 500
# Enter the 2 element: Apple
# ('Apple', 500)
# <class 'tuple'>
# <class 'int'>

# %%
# String operation

x=input("Enter a word: ").strip()
z=x.lower()
y=z[ : :-1]#reversing a word
if y==z:
 print(f" {x} is a palindrome")
else:
 print(f" {x} is not a palindrome")
print(x.upper())# turns into capital letters
print(x.lower())# turns into small letters
print(x[1:4:1])# [start:stop:step]
print(x[ :3: ])# stops at index 3(index 3 excluded)
print(x[3: : ])# starts from index 3(index 3 included)
print(x[ : :2])# used to jump between characters(default settings is 1)
print(x.strip())# removes spaces
print(x.isdigit())# checks is digit
print(x.isalpha())# checks if alphabet
split=x.split(",")# converts string to list
print(split)
join=("-").join(split)# converts list to string
print(join)
# Out:
# Enter a word: Naman
#  Naman is a palindrome
# NAMAN
# naman
# ama
# Nam
# an
# Nmn
# Naman
# False
# True
# ['Naman']
# Naman

# %%
# Swap Numbers

a,b=map(int,input("Enter 2 no. separated by space: ").split())
a,b = b,a
print(f"Swapped nos.: {a,b}")
# Out:
# Enter 2 no. separated by space: 1 2
# Swapped nos.: (2, 1)

# %%
# Swap an arr of 4 elements

arr=list(map(int,input("Enter 4 no. separated by space: ").split()))
arr[0],arr[3]=arr[3],arr[0]
print(f"Your reversed array is: {arr}")
# Out:
# Enter 4 no. separated by space: 4 3 2 1
# Your reversed array is: [1, 3, 2, 4]

# %%
a="Python"
print(a[0])
# Out:
# P

# %%
import os

USERNAME = "Sumit-Ghosh-771J"
TOKEN = "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"  # your full token
REPO_NAME = "dsa-python"
NOTEBOOK_NAME = "01_Arrays.ipynb"
COMMIT_MSG = "Update array practice solutions"

# 1. Ensure the active notebook is written to the environment
from google.colab import _message
import json

try:
    notebook_json = _message.blocking_request('get_ipynb')
    with open(f"/content/{NOTEBOOK_NAME}", "w") as f:
        json.dump(notebook_json['ipynb'], f)
except Exception:
    pass

# 2. Configure Git identity
# !git config --global user.name "{USERNAME}"
# !git config --global user.email "{USERNAME}@users.noreply.github.com"

# 3. Clone, copy, and push
# !rm -rf github_repo
# !git clone https://{TOKEN}@github.com/{USERNAME}/{REPO_NAME}.git github_repo
# !cp /content/{NOTEBOOK_NAME} github_repo/

# %cd github_repo
# !git add {NOTEBOOK_NAME}
# !git commit -m "{COMMIT_MSG}"
# !git push origin main
# %cd /content
# !rm -rf github_repo

print(" Successfully pushed to GitHub!")
